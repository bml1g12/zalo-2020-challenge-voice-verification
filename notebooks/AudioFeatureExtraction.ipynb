# %%
import essentia
import essentia.standard as es
import glob
import os
import librosa
import soundfile as sf
from essentia.standard import *
import numpy as np
import ntpath
import pandas as pd
import logging
from multiprocessing import Pool
import traceback
logging.basicConfig(filename='audio_feature_extraction.log',level=logging.DEBUG)

import argparse

def get_audio_features(f):
    features, features_frames = es.MusicExtractor(
                                              lowlevelStats=['mean', 'stdev'],
                                              rhythmStats=['mean', 'stdev'],
                                              tonalStats=['mean', 'stdev'],
                                             )(f)
    features_name = features.descriptorNames()
    features_name = list(filter(lambda name: "metadata" not in name,features_name))
    info = {}
    for f in features_name:
        if not isinstance(features[f], np.ndarray):
            info[f] = features[f]
    
    return info

def task(file, ID):
    try:
        feature = get_audio_features(file)
        logging.info("processed file {}".format(file))
        return (feature, ID)
    except Exception as e:
        logging.error(traceback.format_exc())
        return (None, None)

    
def get_all_audio_features_parallel(list_dir, out_csv):
    files = []
    for directory in list_dir:
        files += glob.glob(directory + "/*.wav")
    
    IDs = [ntpath.basename(f).replace(".mp3", "").replace(".wav", "") for f in files]
    
    with Pool(processes=7) as pool:
        in_out = pool.starmap(task, list(zip(files, IDs)))

        
    in_out = [p  for p in in_out if p[0] is not None]
    input, output = zip(*in_out)    
    features = np.array(input)
    IDs = np.array(output)
    
    keys = features[0].keys()
    data = {}
    data["ID"] = IDs
    for k in keys:
        data[k] = [feature[k] for feature in features]
        
        
    df = pd.DataFrame(data=data)
    
    df.to_csv(out_csv)
    
#get_all_audio_features_parallel(list_dir=in_wav_dirs, out_csv=csv_path)
# get_all_audio_features_parallel(["/data/zalo/hit-song-prediction/train-wav-samples", "/data/zalo/hit-song-prediction/test-wav-samples"])

# %%
in_wav_dirs = "/media/ben/datadrive/Zalo/voice-verification/Train-Test-Data/public-test/" #Video directories that contains wav files
out_csv = "features.csv"
get_audio_features(os.path.join(in_wav_dirs, "0auqADJgo6MHz2ET5vv4.wav"))
# Out:
# {'lowlevel.average_loudness': 0.9797549247741699,
#  'lowlevel.barkbands_crest.mean': 15.558675765991211,
#  'lowlevel.barkbands_crest.stdev': 5.068912029266357,
#  'lowlevel.barkbands_flatness_db.mean': 0.4248653054237366,
#  'lowlevel.barkbands_flatness_db.stdev': 0.07999197393655777,
#  'lowlevel.barkbands_kurtosis.mean': 10.325821876525879,
#  'lowlevel.barkbands_kurtosis.stdev': 16.852739334106445,
#  'lowlevel.barkbands_skewness.mean': 1.0736998319625854,
#  'lowlevel.barkbands_skewness.stdev': 1.4764575958251953,
#  'lowlevel.barkbands_spread.mean': 4.976924419403076,
#  'lowlevel.barkbands_spread.stdev': 4.354218006134033,
#  'lowlevel.dissonance.mean': 0.32215598225593567,
#  'lowlevel.dissonance.stdev': 0.07955385744571686,
#  'lowlevel.dynamic_complexity': 2.355710744857788,
#  'lowlevel.erbbands_crest.mean': 16.084442138671875,
#  'lowlevel.erbbands_crest.stdev': 5.316064357757568,
#  'lowlevel.erbbands_flatness_db.mean': 0.37523046135902405,
#  'lowlevel.erbbands_flatness_db.stdev': 0.05358386039733887,
#  'lowlevel.erbbands_kurtosis.mean': 6.612517356872559,
#  'lowlevel.erbbands_kurtosis.stdev': 8.551218032836914,
#  'lowlevel.erbbands_skewness.mean': 1.5008991956710815,
#  'lowlevel.erbbands_skewness.stdev': 1.4109362363815308,
#  'lowlevel.erbbands_spread.mean': 12.76298713684082,
#  'lowlevel.erbbands_spread.stdev': 10.313570976257324,
#  'lowlevel.hfc.mean': 8.522685050964355,
#  'lowlevel.hfc.stdev': 6.10125732421875,
#  'lowlevel.loudness_ebu128.integrated': -16.943490982055664,
#  'lowlevel.loudness_ebu128.loudness_range': 0.4210643768310547,
#  'lowlevel.loudness_ebu128.momentary.mean': -17.235435485839844,
#  'lowlevel.loudness_ebu128.momentary.stdev': 1.6645560264587402,
#  'lowlevel.loudness_ebu128.short_term.mean': -17.307912826538086,
#  'lowlevel.loudness_ebu128.short_term.stdev': 0.14841806888580322,
#  'lowlevel.melbands_crest.mean': 20.70124626159668,
#  'lowlevel.melbands_crest.stdev': 5.820700645446777,
#  'lowlevel.melbands_flatness_db.mean': 0.5158348083496094,
#  'lowlevel.melbands_flatness_db.stdev': 0.09128434956073761,
#  'lowlevel.melbands_kurtosis.mean': 19.287822723388672,
#  'lowlevel.melbands_kurtosis.stdev': 23.569746017456055,
#  'lowlevel.melbands_skewness.mean': 2.528217315673828,
#  'lowlevel.melbands_skewness.stdev': 1.8822870254516602,
#  'lowlevel.melbands_spread.mean': 5.08219575881958,
#  'lowlevel.melbands_spread.stdev': 5.294877529144287,
#  'lowlevel.pitch_salience.mean': 0.45410510897636414,
#  'lowlevel.pitch_salience.stdev': 0.14956055581569672,
#  'lowlevel.silence_rate_20dB.mean': 1.0,
#  'lowlevel.silence_rate_20dB.stdev': 0.0,
#  'lowlevel.silence_rate_30dB.mean': 0.9891892075538635,
#  'lowlevel.silence_rate_30dB.stdev': 0.10341133922338486,
#  'lowlevel.silence_rate_60dB.mean': 0.04324324429035187,
#  'lowlevel.silence_rate_60dB.stdev': 0.20340439677238464,
#  'lowlevel.spectral_centroid.mean': 356.736572265625,
#  'lowlevel.spectral_centroid.stdev': 168.8199920654297,
#  'lowlevel.spectral_complexity.mean': 5.513513565063477,
#  'lowlevel.spectral_complexity.stdev': 2.840076446533203,
#  'lowlevel.spectral_decrease.mean': -9.433304803962983e-09,
#  'lowlevel.spectral_decrease.stdev': 6.8131904562562795e-09,
#  'lowlevel.spectral_energy.mean': 0.036376483738422394,
#  'lowlevel.spectral_energy.stdev': 0.02617834135890007,
#  'lowlevel.spectral_energyband_high.mean': 3.9560868572152685e-06,
#  'lowlevel.spectral_energyband_high.stdev': 7.532578820246272e-06,
#  'lowlevel.spectral_energyband_low.mean': 0.002262918744236231,
#  'lowlevel.spectral_energyband_low.stdev': 0.0024282438680529594,
#  'lowlevel.spectral_energyband_middle_high.mean': 0.0009487957577221096,
#  'lowlevel.spectral_energyband_middle_high.stdev': 0.0018513866234570742,
#  'lowlevel.spectral_energyband_middle_low.mean': 0.02864198200404644,
#  'lowlevel.spectral_energyband_middle_low.stdev': 0.023370875045657158,
#  'lowlevel.spectral_entropy.mean': 5.287509441375732,
#  'lowlevel.spectral_entropy.stdev': 0.8319675922393799,
#  'lowlevel.spectral_flux.mean': 0.08197254687547684,
#  'lowlevel.spectral_flux.stdev': 0.04797415807843208,
#  'lowlevel.spectral_kurtosis.mean': 55.72154235839844,
#  'lowlevel.spectral_kurtosis.stdev': 45.26183319091797,
#  'lowlevel.spectral_rms.mean': 0.00556274875998497,
#  'lowlevel.spectral_rms.stdev': 0.002131918678060174,
#  'lowlevel.spectral_rolloff.mean': 387.0155334472656,
#  'lowlevel.spectral_rolloff.stdev': 257.7518005371094,
#  'lowlevel.spectral_skewness.mean': 5.145699977874756,
#  'lowlevel.spectral_skewness.stdev': 2.586211681365967,
#  'lowlevel.spectral_spread.mean': 1775897.375,
#  'lowlevel.spectral_spread.stdev': 1767538.0,
#  'lowlevel.spectral_strongpeak.mean': 0.9854508638381958,
#  'lowlevel.spectral_strongpeak.stdev': 0.817039966583252,
#  'lowlevel.zerocrossingrate.mean': 0.01425517350435257,
#  'lowlevel.zerocrossingrate.stdev': 0.0075341179035604,
#  'rhythm.beats_count': 6.0,
#  'rhythm.beats_loudness.mean': 0.03411256894469261,
#  'rhythm.beats_loudness.stdev': 0.027921007946133614,
#  'rhythm.bpm': 97.1615982055664,
#  'rhythm.bpm_histogram_first_peak_bpm': 96.0,
#  'rhythm.bpm_histogram_first_peak_weight': 0.6000000238418579,
#  'rhythm.bpm_histogram_second_peak_bpm': 0.0,
#  'rhythm.bpm_histogram_second_peak_spread': 0.0,
#  'rhythm.bpm_histogram_second_peak_weight': 0.0,
#  'rhythm.danceability': 1.2235281467437744,
#  'rhythm.onset_rate': 4.668445110321045,
#  'tonal.chords_changes_rate': 0.08602150529623032,
#  'tonal.chords_number_rate': 0.05376344174146652,
#  'tonal.chords_strength.mean': 0.5740600228309631,
#  'tonal.chords_strength.stdev': 0.09146493673324585,
#  'tonal.hpcp_crest.mean': 16.050859451293945,
#  'tonal.hpcp_crest.stdev': 7.185327529907227,
#  'tonal.hpcp_entropy.mean': 1.58894681930542,
#  'tonal.hpcp_entropy.stdev': 0.6800828576087952,
#  'tonal.key_edma.strength': 0.4772377610206604,
#  'tonal.key_krumhansl.strength': 0.4778122305870056,
#  'tonal.key_temperley.strength': 0.4615934193134308,
#  'tonal.tuning_diatonic_strength': 0.617395281791687,
#  'tonal.tuning_equal_tempered_deviation': 0.26668861508369446,
#  'tonal.tuning_frequency': 437.7185363769531,
#  'tonal.tuning_nontempered_energy_ratio': 0.8833489418029785,
#  'tonal.chords_key': 'Ab',
#  'tonal.chords_scale': 'major',
#  'tonal.key_edma.key': 'F',
#  'tonal.key_edma.scale': 'minor',
#  'tonal.key_krumhansl.key': 'F',
#  'tonal.key_krumhansl.scale': 'minor',
#  'tonal.key_temperley.key': 'F',
#  'tonal.key_temperley.scale': 'minor'}
